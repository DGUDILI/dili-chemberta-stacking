# %%
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, GradientBoostingClassifier, HistGradientBoostingClassifier
from xgboost import XGBClassifier

models = {
    'RF': RandomForestClassifier(),
    'ET': ExtraTreesClassifier(),
    'HistGB': HistGradientBoostingClassifier(),
    'XGBoost': XGBClassifier(use_label_encoder=False, eval_metric='logloss'),
}

# %%
from sklearn.metrics import accuracy_score, roc_auc_score, matthews_corrcoef
import pickle
import pandas as pd
import numpy as np
import os

data_path = "../Feature/Feature.csv"
data = pd.read_csv(data_path)


train_data = data[data['ref'] != 'DILIrank']
test_data = data[data['ref'] == 'DILIrank']


X_train = train_data.drop(['SMILES', 'Label', 'ref'], axis=1)
y_train = train_data['Label']
X_test = test_data.drop(['SMILES', 'Label', 'ref'], axis=1)
y_test = test_data['Label']

save_path = "../Model/"
os.makedirs(save_path, exist_ok=True) 

for model_name, model in models.items():
    print(f"正在训练模型: {model_name}")

    best_auc = -np.inf  
    best_model = None


    for i in range(5):
        print(f"第 {i + 1} 次训练...")

       
        model.set_params(random_state=np.random.randint(0, 10000))

      
        model.fit(X_train, y_train)

        y_pred = model.predict(X_test)
        y_prob = model.predict_proba(X_test)[:, 1]  

        
        acc = accuracy_score(y_test, y_pred)
        auc = roc_auc_score(y_test, y_prob)
        mcc = matthews_corrcoef(y_test, y_pred)

        print(f"第 {i + 1} 次训练结果 - {model_name}: ACC: {acc:.4f}, AUC: {auc:.4f}, MCC: {mcc:.4f}")

        
        if auc > best_auc:
            best_auc = auc
            best_model = pickle.dumps(model) 
   
    model_file = os.path.join(save_path, f"best_model_{model_name}.pkl")
    
    
    with open(model_file, 'wb') as f:
        f.write(best_model)
    print(f"模型 {model_name} 的最佳AUC: {best_auc:.4f}，已保存为 {model_file}")
# Out:
# 正在训练模型: RF
# 第 1 次训练...
# 第 1 次训练结果 - RF: ACC: 0.9159, AUC: 0.9767, MCC: 0.8312
# 第 2 次训练...
# 第 2 次训练结果 - RF: ACC: 0.9093, AUC: 0.9727, MCC: 0.8191
# 第 3 次训练...
# 第 3 次训练结果 - RF: ACC: 0.9049, AUC: 0.9749, MCC: 0.8090
# 第 4 次训练...
# 第 4 次训练结果 - RF: ACC: 0.9049, AUC: 0.9763, MCC: 0.8090
# 第 5 次训练...
# 第 5 次训练结果 - RF: ACC: 0.9137, AUC: 0.9762, MCC: 0.8263
# 模型 RF 的最佳AUC: 0.9767，已保存为 ../Model/best_model_RF.pkl
# 正在训练模型: ET
# 第 1 次训练...
# 第 1 次训练结果 - ET: ACC: 0.9159, AUC: 0.9734, MCC: 0.8321
# 第 2 次训练...
# 第 2 次训练结果 - ET: ACC: 0.9226, AUC: 0.9735, MCC: 0.8453
# 第 3 次训练...
# 第 3 次训练结果 - ET: ACC: 0.9204, AUC: 0.9742, MCC: 0.8403
# 第 4 次训练...
# 第 4 次训练结果 - ET: ACC: 0.9159, AUC: 0.9737, MCC: 0.8304
# 第 5 次训练...
# 第 5 次训练结果 - ET: ACC: 0.9270, AUC: 0.9741, MCC: 0.8552
# 模型 ET 的最佳AUC: 0.9742，已保存为 ../Model/best_model_ET.pkl
# 正在训练模型: HistGB
# 第 1 次训练...
# 第 1 次训练结果 - HistGB: ACC: 0.9071, AUC: 0.9686, MCC: 0.8151
# 第 2 次训练...
# 第 2 次训练结果 - HistGB: ACC: 0.9071, AUC: 0.9686, MCC: 0.8151
# 第 3 次训练...
# 第 3 次训练结果 - HistGB: ACC: 0.9071, AUC: 0.9686, MCC: 0.8151
# 第 4 次训练...
# 第 4 次训练结果 - HistGB: ACC: 0.9071, AUC: 0.9686, MCC: 0.8151
# 第 5 次训练...
# 第 5 次训练结果 - HistGB: ACC: 0.9071, AUC: 0.9686, MCC: 0.8151
# 模型 HistGB 的最佳AUC: 0.9686，已保存为 ../Model/best_model_HistGB.pkl
# 正在训练模型: XGBoost
# 第 1 次训练...
# c:\Users\user\miniconda3\envs\stackdili\lib\site-packages\xgboost\training.py:200: UserWarning: [17:08:50] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\user\miniconda3\envs\stackdili\lib\site-packages\xgboost\training.py:200: UserWarning: [17:08:50] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# 第 1 次训练结果 - XGBoost: ACC: 0.9137, AUC: 0.9620, MCC: 0.8271
# 第 2 次训练...
# 第 2 次训练结果 - XGBoost: ACC: 0.9137, AUC: 0.9620, MCC: 0.8271
# 第 3 次训练...
# c:\Users\user\miniconda3\envs\stackdili\lib\site-packages\xgboost\training.py:200: UserWarning: [17:08:51] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# c:\Users\user\miniconda3\envs\stackdili\lib\site-packages\xgboost\training.py:200: UserWarning: [17:08:51] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# 第 3 次训练结果 - XGBoost: ACC: 0.9137, AUC: 0.9620, MCC: 0.8271
# 第 4 次训练...
# 第 4 次训练结果 - XGBoost: ACC: 0.9137, AUC: 0.9620, MCC: 0.8271
# 第 5 次训练...
# 第 5 次训练结果 - XGBoost: ACC: 0.9137, AUC: 0.9620, MCC: 0.8271
# 模型 XGBoost 的最佳AUC: 0.9620，已保存为 ../Model/best_model_XGBoost.pkl
# c:\Users\user\miniconda3\envs\stackdili\lib\site-packages\xgboost\training.py:200: UserWarning: [17:08:51] WARNING: C:\actions-runner\_work\xgboost\xgboost\src\learner.cc:782:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
